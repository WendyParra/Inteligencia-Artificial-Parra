# %% [markdown]
# <a href="https://colab.research.google.com/github/WendyParra/Inteligencia-Artificial-Parra/blob/main/Evaluaci%C3%B3n_PARRA_U1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Crear un notebook en colab a partir del programa base de la compuerta AND Modificar para que funcione con las dos compuertas AND y OR

# %%
def valores():
    # Recibir los valores de entrada
    x1 = int(input('Ingrese X0 (0 o 1): '))  # Recibir dato X0
    x2 = int(input('Ingrese X1 (0 o 1): '))  # Recibir dato X1
    x = [x1, x2]  # Guardar valores
    w = [1, 1]  # Pesos para las dos compuertas

    # Compuerta AND
    s_and = -1.5  # Sesgo ajustado para compuerta AND
    for i in range(2):
        s_and = s_and + x[i] * w[i]
    y_and = 1 if s_and >= 0 else 0  # Resultado de AND
    print(f"\n{x[0]} AND {x[1]} = {y_and}")

    # Compuerta OR
    s_or = -0.5  # Sesgo ajustado para compuerta OR
    for i in range(2):
        s_or = s_or + x[i] * w[i]
    y_or = 1 if s_or >= 0 else 0  # Resultado de OR
    print(f"{x[0]} OR {x[1]} = {y_or}")
    print('\n')

# %% [markdown]
# Se crea el menú de opciones

# %%
#Funcion salir
def salir():
  print('Fin del programa')

# %%
#se crea la lista de opciones
opciones = {
   '1': ('agregar nuevo dato', valores),
   '2': ('salir', salir)
}

# %%
#Menú funcionando
print("\n\n\nBienvenido, ¿qué desea realizar?")
while True:
    for clave, valor in opciones.items():
        print(f"{clave}: {valor[0]}")

    seleccion = input("\nSelecciona una opción: ")

    if seleccion in opciones:
        opciones[seleccion][1]()  # Ejecuta la función correspondiente
        if seleccion == '2':  # salir del programa
            break
    else:
        print("Opción no válida, intenta de nuevo.")
# Out:
# Bienvenido, ¿qué desea realizar?
# 1: agregar nuevo dato
# 2: salir
#
# Selecciona una opción: 1
# Ingrese X0 (0 o 1): 0
# Ingrese X1 (0 o 1): 0
#
# 0 AND 0 = 0
# 0 OR 0 = 0
#
#
# 1: agregar nuevo dato
# 2: salir
#
# Selecciona una opción: 1
# Ingrese X0 (0 o 1): 0
# Ingrese X1 (0 o 1): 1
#
# 0 AND 1 = 0
# 0 OR 1 = 1
#
#
# 1: agregar nuevo dato
# 2: salir
#
# Selecciona una opción: 1
# Ingrese X0 (0 o 1): 1
# Ingrese X1 (0 o 1): 0
#
# 1 AND 0 = 0
# 1 OR 0 = 1
#
#
# 1: agregar nuevo dato
# 2: salir
#
# Selecciona una opción: 1
# Ingrese X0 (0 o 1): 1
# Ingrese X1 (0 o 1): 1
#
# 1 AND 1 = 1
# 1 OR 1 = 1
#
#
# 1: agregar nuevo dato
# 2: salir
#
# Selecciona una opción: 2
# Fin del programa
